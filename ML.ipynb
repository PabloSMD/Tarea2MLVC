# %% [markdown]
# # Tarea 1: Técnicas de Machine Learning para la clasificación de imágenes
# #### Integrantes:&ensp;&ensp;Claudio Macher Chávez
# #### &ensp;&ensp;&ensp;&ensp;&ensp;&ensp;&ensp;&ensp;&ensp;&ensp;&ensp;&ensp;Pablo San Martín Domínguez
# ### Importaciones y configuración inicial:

# %%
import numpy as np 
import cv2
import glob
import os
import matplotlib.pyplot as plt
import string
from mlxtend.plotting import plot_decision_regions
from mpl_toolkits.mplot3d import Axes3D
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier 
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.utils.multiclass import unique_labels
from sklearn import metrics
from sklearn.svm import SVC
ruta = "./archivo"
print(os.listdir(ruta))
dim = 100
# Out:
# ['animals', 'name of the animals.txt']

# %% [markdown]
# ### Obtener dataset de los animales seleccionados:

# %%
def getAnimales(animales, data_type, print_n=False, k_fold=False):
    images = []
    labels = []
    val = ['Entrenamiento', 'Testing']
    if not k_fold:
        path = ruta + "/animals/" + data_type + "/"
        for i,f in enumerate(animales):
            p = path + f
            j=0
            for image_path in glob.glob(os.path.join(p, "*.jpg")):
                image = cv2.imread(image_path, cv2.IMREAD_COLOR)
                image = cv2.resize(image, (dim, dim))
                image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
                images.append(image)
                labels.append(i)
                j+=1
            if(print_n):
                print("Existen " , j , " imágenes de  " , data_type.upper(), " de " , animales[i].upper())
        images = np.array(images)
        labels = np.array(labels)
        return images, labels
    else:
        for v in val:
            path = ruta + "/animals/" + v + "/"
            for i,f in enumerate(animales):
                p = path + f
                j=0
                for image_path in glob.glob(os.path.join(p, "*.jpg")):
                    image = cv2.imread(image_path, cv2.IMREAD_COLOR)
                    image = cv2.resize(image, (dim, dim))
                    image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
                    images.append(image)
                    labels.append(i)
                    j+=1
        images = np.array(images)
        labels = np.array(labels)
        return images, labels

# %% [markdown]
# ### Escoge tus animales para clasificación binaria:

# %%
#Escoge tus animales
animales = ['leopard' , 'shark'] # Clasificación binaria

#Get Images and Labels 
X_t, y_train =  getAnimales(animales, 'Entrenamiento', print_n=True, k_fold=False)
X_test, y_test = getAnimales(animales, 'Testing', print_n=True, k_fold=False)

#Get data for k-fold
X,y = getAnimales(animales, '', print_n=True, k_fold=True)

#Scale Data Images
scaler = StandardScaler()
X_train = scaler.fit_transform([i.flatten() for i in X_t])
X_test = scaler.fit_transform([i.flatten() for i in X_test])
X = scaler.fit_transform([i.flatten() for i in X])
# Out:
# Existen  50  imágenes de   ENTRENAMIENTO  de  LEOPARD
# Existen  50  imágenes de   ENTRENAMIENTO  de  SHARK
# Existen  10  imágenes de   TESTING  de  LEOPARD
# Existen  10  imágenes de   TESTING  de  SHARK

# %% [markdown]
# #### Se define la función para mostrar las imágenes en una grilla:

# %%
def plot_image_grid(images, nb_rows, nb_cols, figsize=(15, 15)):
    assert len(images) == nb_rows*nb_cols, "Number of images should be the same as (nb_rows*nb_cols)"
    fig, axs = plt.subplots(nb_rows, nb_cols, figsize=figsize)
    
    n = 0
    for i in range(0, nb_rows):
        for j in range(0, nb_cols):
            axs[i, j].axis('off')
            axs[i, j].imshow(images[n])
            n += 1

# %% [markdown]
# #### Se muestra la cuadrícula de imágenes de entrenamiento del primer animal:

# %%
print(animales[y_train[0]])
plot_image_grid(X_t[0:50], 5, 10)
# Out:
# leopard

# %%
print(animales[y_train[50]])
plot_image_grid(X_t[50:100], 5, 10)
# Out:
# shark

# %%
def getClassNumber(y):
    v =[]
    i=0
    count = 0
    for index in y:
        if(index == i):
            count +=1
        else:
            v.append(count)
            count = 1
            i +=1
    v.append(count)        
    return v

# %%
def plotPrincipalComponents(X, dim):
    v = getClassNumber(y_train)
    colors = 'b', 'g', 'r', 'c', 'm', 'y', 'k', 'grey', 'orange', 'purple'
    markers = ['o', 'x' , 'v', 'd']
    tot = len(X)
    start = 0
    if(dim == 2):
        for i,index in enumerate(v):
            end = start + index
            plt.scatter(X[start:end,0],X[start:end,1] , color=colors[i%len(colors)], marker=markers[i%len(markers)], label = animales[i])
            start = end
        plt.xlabel('PC1')
        plt.ylabel('PC2')
   
    if(dim == 3):
        fig = plt.figure()
        ax = fig.add_subplot(111, projection='3d')
        for i,index in enumerate(v):
            end = start + index
            ax.scatter(X[start:end,0], X[start:end,1], X[start:end,2], color=colors[i%len(colors)], marker=markers[i%len(markers)], label = animales[i])
            start = end
        ax.set_xlabel('PC1')
        ax.set_ylabel('PC2')
        ax.set_zlabel('PC3')


    plt.legend(loc='lower left')
    plt.xticks()
    plt.yticks()
    plt.show()

# %%
def plot_confusion_matrix(y_true, y_pred, classes,
                          normalize=False,
                          title=None,
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if not title:
        if normalize:
            title = 'Normalized confusion matrix'
        else:
            title = 'Confusion matrix, without normalization'

    # Compute confusion matrix
    cm = metrics.confusion_matrix(y_true, y_pred)
    # Only use the labels that appear in the data
    classes = unique_labels(y_true, y_pred)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    fig, ax = plt.subplots()
    im = ax.imshow(cm, interpolation='nearest', cmap=cmap)
    ax.figure.colorbar(im, ax=ax)
    # We want to show all ticks...
    ax.set(xticks=np.arange(cm.shape[1]),
           yticks=np.arange(cm.shape[0]),
           # ... and label them with the respective list entries
           xticklabels=animales, yticklabels=animales,
           title=title,
           ylabel='True label',
           xlabel='Predicted label')

    # Rotate the tick labels and set their alignment.
    plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
             rotation_mode="anchor")

    # Loop over data dimensions and create text annotations.
    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            ax.text(j, i, format(cm[i, j], fmt),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    fig.tight_layout()
    return cm,ax

# %%
pca = PCA(n_components=2)
dataIn2D = pca.fit_transform(X_train)
plotPrincipalComponents(dataIn2D, 2)

# %%
pca = PCA(n_components=3)
dataIn3D = pca.fit_transform(X_train)
plotPrincipalComponents(dataIn3D, 3)

# %% [markdown]
# ### IMPLEMENTACIÓN DE ALGORITMO SVM

# %%
svm = SVC(gamma='auto', kernel='linear', probability=True)
svm.fit(X_train, y_train)
y_pred = svm.predict(X_test)

#Evaluation
precision = metrics.accuracy_score(y_pred, y_test) * 100
print("Accuracy with SVM: {0:.2f}%".format(precision))
cm , _ = plot_confusion_matrix(y_test, y_pred,classes=y_train,
normalize=True, title='Normalized confusion matrix')
plt.show()

# calculate the FPR and TPR for all thresholds of the classification
probs = svm.predict_proba(X_test)
probs = probs[:, 1]
svm_fpr, svm_tpr, thresholds = metrics.roc_curve(y_test, probs)
svm_auc = metrics.roc_auc_score(y_test, probs)
# Out:
# Accuracy with SVM: 100.00%

# %% [markdown]
# ### SVM + K-FOLD

# %%
pred_kfold = cross_val_score(svm, X, y, cv=5)
print("Accuracy with SVM and K-FOLD CROSS VALIDATION: %0.2f (+/- %0.2f)" % (pred_kfold.mean(), pred_kfold.std() * 2))
# Out:
# Accuracy with SVM and K-FOLD CROSS VALIDATION: 0.96 (+/- 0.05)

# %% [markdown]
# ### IMPLEMENTACIÓN DE ALGORITMO KNN

# %%
knn = KNeighborsClassifier(n_neighbors=2)
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)

#Evaluation
precision = metrics.accuracy_score(y_pred, y_test) * 100
print("Accuracy with K-NN: {0:.2f}%".format(precision))
cm , _ = plot_confusion_matrix(y_test, y_pred, classes=y_train, normalize=True, title='Normalizedconfusion matrix')
plt.show()

# calculate the FPR and TPR for all thresholds of the classification
probs = knn.predict_proba(X_test)
probs = probs[:, 1]
knn_fpr, knn_tpr, thresholds = metrics.roc_curve(y_test, probs)
knn_auc = metrics.roc_auc_score(y_test, probs)
# Out:
# Accuracy with K-NN: 95.00%

# %% [markdown]
# ### KNN + K-FOLD

# %%
pred_kfold = cross_val_score(knn, X, y, cv=5)
print("Accuracy with K-NN and K-FOLD CROSS VALIDATION: %0.2f (+/- %0.2f)" %
(pred_kfold.mean(), pred_kfold.std() * 2))
# Out:
# Accuracy with K-NN and K-FOLD CROSS VALIDATION: 0.94 (+/- 0.07)

# %% [markdown]
# ### Gráfico respecto al cambio de los valores de K

# %%
#Cambio de los valores de K
accuracy_train = []
accuracy_test = []

for i in range(1,15):   #check all possible values for 1 to 15
    k_nn = KNeighborsClassifier(n_neighbors=i)
    k_nn.fit(X_train,y_train)
    pred_i = k_nn.predict(X_test)
    accuracy_train.append(k_nn.score(X_train,y_train)*100)
    accuracy_test.append(k_nn.score(X_test,y_test)*100)
    
accuracy_train_array=np.asarray(accuracy_train)
accuracy_test_array=np.asarray(accuracy_test)
    
plt.figure(figsize=(10,6))
plt.plot(range(1,15),accuracy_train_array, label='Training_Accuracy', color='blue')
plt.plot(range(1,15),accuracy_test_array, label='Testing_Accuracy', color='red')
plt.legend()
plt.title('Accuracy vs K value')
plt.xlabel('K')
plt.ylabel('Accuracy%')

plt.show()

# %% [markdown]
# ### IMPLEMENTACIÓN DE ALGORITMO ÁRBOL DE DECISIÓN

# %%
tree = DecisionTreeClassifier()
tree = tree.fit(X_train,y_train)
y_pred = tree.predict(X_test)

#Evaluation
precision = metrics.accuracy_score(y_pred, y_test) * 100
print("Accuracy with Decision Tree: {0:.2f}%".format(precision))
cm , _ = plot_confusion_matrix(y_test, y_pred, classes=y_train, normalize=True, title='Normalized confusion matrix')
plt.show()

# calculate the FPR and TPR for all thresholds of the classification
probs = tree.predict_proba(X_test)
probs = probs[:, 1]
tree_fpr, tree_tpr, thresholds = metrics.roc_curve(y_test, probs)
tree_auc = metrics.roc_auc_score(y_test, probs)
# Out:
# Accuracy with Decision Tree: 65.00%

# %% [markdown]
# ### DECISION TREE + K-FOLD

# %%
pred_kfold = cross_val_score(tree, X, y, cv=5) 
print("Accuracy with DECISION TREE and K-FOLD CROSS VALIDATION: %0.2f (+/- %0.2f)" % (pred_kfold.mean(), pred_kfold.std() * 2))
# Out:
# Accuracy with DECISION TREE and K-FOLD CROSS VALIDATION: 0.82 (+/- 0.06)

# %% [markdown]
# ### Gráfico de cambio de la profundidad máxima

# %%
# Cambiando la profundidad máxima
score_train=[]
score_test=[]

for i in range(1,10):
    dtree_md = DecisionTreeClassifier(max_depth=i)
    dtree_md.fit(X_train,y_train)
    
    score_train.append(dtree_md.score(X_train,y_train)*100)
    score_test.append(dtree_md.score(X_test,y_test)*100)
    
score_train_array=np.asarray(score_train)
score_test_array=np.asarray(score_test)
plt.figure(figsize=(10,6))
plt.plot(range(1,10),score_train_array,color='blue', label="Training_accuracy")
plt.plot(range(1,10),score_test_array,color='red',label="Testing_accuracy")

plt.legend()
plt.xlabel('max_depth')
plt.ylabel('Accuracy%')
plt.show()

# %% [markdown]
# ### CARACTERÍSTICAS OPERATIVAS DEL RECEPTOR

# %%
#ROC CURVE
plt.title('ROC Curve')
plt.plot([0, 1], [0, 1], linestyle='--')
plt.plot(svm_fpr, svm_tpr, 'b', marker='.', label = 'SVM = %0.3f' % svm_auc )
plt.plot(knn_fpr, knn_tpr, 'g', marker='.', label = 'KNN = %0.3f' % knn_auc)
plt.plot(tree_fpr, tree_tpr, 'r', marker='.',label = 'ARBOL DE DECISIÓN = %.3f' % tree_auc)
plt.legend(loc = 'lower right')
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %% [markdown]
# ### Definición de las técnicas como funciones

# %% [markdown]
# #### Función para obtener dataset de los animales seleccionados:

# %%
def cargarDatasets(animales):
    X_t, y_train =  getAnimales(animales, 'Entrenamiento', print_n=True, k_fold=False)
    X_test, y_test = getAnimales(animales, 'Testing', print_n=True, k_fold=False)
    X,y = getAnimales(animales, '', print_n=True, k_fold=True)
    scaler = StandardScaler()
    X_train = scaler.fit_transform([i.flatten() for i in X_t])
    X_test = scaler.fit_transform([i.flatten() for i in X_test])
    X = scaler.fit_transform([i.flatten() for i in X])

# %% [markdown]
# #### Función para aplicar SVM:

# %%
def aplicarSVM():
    svm = SVC(gamma='auto', kernel='linear', probability=True)
    svm.fit(X_train, y_train)
    y_pred = svm.predict(X_test)
    precision = metrics.accuracy_score(y_pred, y_test) * 100
    return precision

# %% [markdown]
# #### Función para aplicar KNN:

# %%
def aplicarKNN():
    knn = KNeighborsClassifier(n_neighbors=2)
    knn.fit(X_train, y_train)
    y_pred = knn.predict(X_test)
    precision = metrics.accuracy_score(y_pred, y_test) * 100
    return precision

# %% [markdown]
# #### Función para aplicar Decition Tree:

# %%
def aplicarDTree():
    tree = DecisionTreeClassifier()
    tree = tree.fit(X_train,y_train)
    y_pred = tree.predict(X_test)
    precision = metrics.accuracy_score(y_pred, y_test) * 100
    return precision

# %% [markdown]
# #### Impresión de los promedios obtenidos:

# %%
def imprimirPromedios():
    print("Promedio de precisión")
    print("SVM: {0:.2f}%".format(sumaSVM/cantidadDeDuplas))
    print("K-NN: {0:.2f}%".format(sumaKNN/cantidadDeDuplas))
    print("Decision Tree: {0:.2f}%".format(sumaDTree/cantidadDeDuplas))
    print("Promedio general de precisión: {0:.2f}%".format(((sumaSVM/cantidadDeDuplas)+(sumaKNN/cantidadDeDuplas)+(sumaDTree/cantidadDeDuplas))/3))

# %% [markdown]
# #### Se almacenan los nombres de las clases en un arreglo:

# %%
archivoNombres = open(ruta + "/name of the animals.txt", "r")
arreglo = archivoNombres.readlines()
nombres = []
for i in arreglo:
    nombres.append(i.strip('\n'))
archivoNombres.close()

# %% [markdown]
# #### Ejecución de las funciones para calcular el promedio de precisión:

# %%
import random
sumaSVM = 0
sumaKNN = 0
sumaDTree = 0
cantidadDeDuplas = 20
for i in range(cantidadDeDuplas):
    animalesRandom = nombres[random.randint(0,89)], nombres[random.randint(0,89)]
    print(animalesRandom)
    cargarDatasets(animalesRandom)
    sumaSVM += aplicarSVM()
    sumaKNN += aplicarKNN()
    sumaDTree += aplicarDTree()
imprimirPromedios()
# Out:
# ('butterfly', 'dog')
# Existen  50  imágenes de   ENTRENAMIENTO  de  BUTTERFLY
# Existen  50  imágenes de   ENTRENAMIENTO  de  DOG
# Existen  10  imágenes de   TESTING  de  BUTTERFLY
# Existen  10  imágenes de   TESTING  de  DOG
# ('hare', 'raccoon')
# Existen  50  imágenes de   ENTRENAMIENTO  de  HARE
# Existen  50  imágenes de   ENTRENAMIENTO  de  RACCOON
# Existen  10  imágenes de   TESTING  de  HARE
# Existen  10  imágenes de   TESTING  de  RACCOON
# ('dog', 'seahorse')
# Existen  50  imágenes de   ENTRENAMIENTO  de  DOG
# Existen  50  imágenes de   ENTRENAMIENTO  de  SEAHORSE
# Existen  10  imágenes de   TESTING  de  DOG
# Existen  10  imágenes de   TESTING  de  SEAHORSE
# ('orangutan', 'whale')
# Existen  50  imágenes de   ENTRENAMIENTO  de  ORANGUTAN
# Existen  50  imágenes de   ENTRENAMIENTO  de  WHALE
# Existen  10  imágenes de   TESTING  de  ORANGUTAN
# Existen  10  imágenes de   TESTING  de  WHALE
# ('panda', 'oyster')
# Existen  50  imágenes de   ENTRENAMIENTO  de  PANDA
# Existen  50  imágenes de   ENTRENAMIENTO  de  OYSTER
# Existen  10  imágenes de   TESTING  de  PANDA
# Existen  10  imágenes de   TESTING  de  OYSTER
# ('raccoon', 'dog')
# Existen  50  imágenes de   ENTRENAMIENTO  de  RACCOON
# Existen  50  imágenes de   ENTRENAMIENTO  de  DOG
# Existen  10  imágenes de   TESTING  de  RACCOON
# Existen  10  imágenes de   TESTING  de  DOG
# ('snake', 'hare')
# Existen  50  imágenes de   ENTRENAMIENTO  de  SNAKE
# Existen  50  imágenes de   ENTRENAMIENTO  de  HARE
# Existen  10  imágenes de   TESTING  de  SNAKE
# Existen  10  imágenes de   TESTING  de  HARE
# ('bat', 'butterfly')
# Existen  50  imágenes de   ENTRENAMIENTO  de  BAT
# Existen  50  imágenes de   ENTRENAMIENTO  de  BUTTERFLY
# Existen  10  imágenes de   TESTING  de  BAT
# Existen  10  imágenes de   TESTING  de  BUTTERFLY
# ('tiger', 'horse')
# Existen  50  imágenes de   ENTRENAMIENTO  de  TIGER
# Existen  50  imágenes de   ENTRENAMIENTO  de  HORSE
# Existen  10  imágenes de   TESTING  de  TIGER
# Existen  10  imágenes de   TESTING  de  HORSE
# ('okapi', 'raccoon')
# Existen  50  imágenes de   ENTRENAMIENTO  de  OKAPI
# Existen  50  imágenes de   ENTRENAMIENTO  de  RACCOON
# Existen  10  imágenes de   TESTING  de  OKAPI
# Existen  10  imágenes de   TESTING  de  RACCOON
# ('dolphin', 'reindeer')
# Existen  50  imágenes de   ENTRENAMIENTO  de  DOLPHIN
# Existen  50  imágenes de   ENTRENAMIENTO  de  REINDEER
# Existen  10  imágenes de   TESTING  de  DOLPHIN
# Existen  10  imágenes de   TESTING  de  REINDEER
# ('dolphin', 'rat')
# Existen  50  imágenes de   ENTRENAMIENTO  de  DOLPHIN
# Existen  50  imágenes de   ENTRENAMIENTO  de  RAT
# Existen  10  imágenes de   TESTING  de  DOLPHIN
# Existen  10  imágenes de   TESTING  de  RAT
# ('flamingo', 'bison')
# Existen  50  imágenes de   ENTRENAMIENTO  de  FLAMINGO
# Existen  50  imágenes de   ENTRENAMIENTO  de  BISON
# Existen  10  imágenes de   TESTING  de  FLAMINGO
# Existen  10  imágenes de   TESTING  de  BISON
# ('mosquito', 'fly')
# Existen  50  imágenes de   ENTRENAMIENTO  de  MOSQUITO
# Existen  50  imágenes de   ENTRENAMIENTO  de  FLY
# Existen  10  imágenes de   TESTING  de  MOSQUITO
# Existen  10  imágenes de   TESTING  de  FLY
# ('lion', 'octopus')
# Existen  50  imágenes de   ENTRENAMIENTO  de  LION
# Existen  50  imágenes de   ENTRENAMIENTO  de  OCTOPUS
# Existen  10  imágenes de   TESTING  de  LION
# Existen  10  imágenes de   TESTING  de  OCTOPUS
# ('tiger', 'dolphin')
# Existen  50  imágenes de   ENTRENAMIENTO  de  TIGER
# Existen  50  imágenes de   ENTRENAMIENTO  de  DOLPHIN
# Existen  10  imágenes de   TESTING  de  TIGER
# Existen  10  imágenes de   TESTING  de  DOLPHIN
# ('squid', 'rat')
# Existen  50  imágenes de   ENTRENAMIENTO  de  SQUID
# Existen  50  imágenes de   ENTRENAMIENTO  de  RAT
# Existen  10  imágenes de   TESTING  de  SQUID
# Existen  10  imágenes de   TESTING  de  RAT
# ('hedgehog', 'crab')
# Existen  50  imágenes de   ENTRENAMIENTO  de  HEDGEHOG
# Existen  50  imágenes de   ENTRENAMIENTO  de  CRAB
# Existen  10  imágenes de   TESTING  de  HEDGEHOG
# Existen  10  imágenes de   TESTING  de  CRAB
# ('bear', 'raccoon')
# Existen  50  imágenes de   ENTRENAMIENTO  de  BEAR
# Existen  50  imágenes de   ENTRENAMIENTO  de  RACCOON
# Existen  10  imágenes de   TESTING  de  BEAR
# Existen  10  imágenes de   TESTING  de  RACCOON
# ('pigeon', 'hippopotamus')
# Existen  50  imágenes de   ENTRENAMIENTO  de  PIGEON
# Existen  50  imágenes de   ENTRENAMIENTO  de  HIPPOPOTAMUS
# Existen  10  imágenes de   TESTING  de  PIGEON
# Existen  10  imágenes de   TESTING  de  HIPPOPOTAMUS
# Promedio de precisión
# SVM: 100.00%
# K-NN: 95.00%
# Decision Tree: 84.00%
# Promedio general de precisión: 93.00%

# %% [markdown]
# #### Chillán, Chile
# #### Viernes 28 de octubre de 2022
